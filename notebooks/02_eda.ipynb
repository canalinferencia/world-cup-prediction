# %%
import pandas as pd

# %%
df = pd.read_csv("../data/all_matches.csv")
df.rename()
# Out:
#              date home_team     away_team  home_score  away_score  \
# 0      1872-11-30  Scotland       England           0           0
# 1      1873-03-08   England      Scotland           4           2
# 2      1874-03-07  Scotland       England           2           1
# 3      1875-03-06   England      Scotland           2           2
# 4      1876-03-04  Scotland       England           3           0
# ...           ...       ...           ...         ...         ...
# 51641  2026-06-10  Pakistan   Afghanistan           2           0
# 51642  2026-06-10  Portugal       Nigeria           2           1
# 51643  2026-06-10   England    Costa Rica           3           0
# 51644  2026-06-10   Algeria       Bolivia           4           0
# 51645  2026-06-11    Mexico  South Africa           2           0
#
#                        tournament        country  neutral
# 0                        Friendly       Scotland    False
# ...
